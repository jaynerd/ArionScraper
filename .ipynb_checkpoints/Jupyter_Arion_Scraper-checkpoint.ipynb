# %%
import re
import json
import urllib3
from bs4 import BeautifulSoup

# %%
# initialization
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
http = urllib3.PoolManager()
target_urls = []
scrapped_urls = []

# %%
# arion scraper attributes
arion_base_url = 'https://arion.aut.ac.nz/ArionMain/CourseInfo/Information/Qualifications/'
arion_initial_url = 'QualificationTypes.aspx'

target_urls.append(arion_initial_url)

# %%
# arion scrapper methods

# scrap nested urls
def scrap_arion_urls():
    for url in target_urls:
        request = http.request('GET', arion_base_url + url)
        soup = BeautifulSoup(request.data, 'lxml')
        for element in soup.find_all('a', 'Navigation'):
            scrapped_urls.append(element)

# extract entries from scrapped urls, return a dictionary
def get_arion_entries(dictionary_name: str):
    dictionary = {}
    dictionary.setdefault(dictionary_name, {})
    previous_degree: str
    previous_degree = ''
    counter = 0
    for tag in scrapped_urls:
        print(previous_degree)
        if tag.text == previous_degree:
            counter += 1
            temp_text = tag.text + ' ' + str(counter)
            print (temp_text)
            dictionary[dictionary_name].setdefault(temp_text, {})
        else:
            dictionary[dictionary_name].setdefault(tag.text, {})
            previous_degree = tag.text
    return dictionary

# extract paper entries for creating a paper list only
def get_arion_paper_list():
    dictionary = {}
    target_entries = []
    return_text = 'Returning to Qualification Details'
    for tag in scrapped_urls:
        target_entries.append(tag.text)
    while return_text in target_entries:
        target_entries.remove(return_text)
    counter = 0
    for entry in target_entries:
        if counter % 2 is 0:
            dictionary.setdefault(entry, [])
        else:
            dictionary[target_entries[(counter - 1)]] = entry
        counter += 1
    paper_list = []
    for key in dictionary:
        paper_list.append({'value': key, 'synonyms': [key, dictionary[key], re.sub('[^A-Z]', '', dictionary[key])]})
    return paper_list

# extract a set of papers for each degress
def get_arion_course_set(dictionary: dict):
    counter = 0
    for degree in dictionary['qualifications']:
        scrapped_course_urls = []
        request = http.request('GET', arion_base_url + target_urls[counter])
        soup = BeautifulSoup(request.data, 'lxml')
        for element in soup.find_all('a', 'Navigation'):
            scrapped_course_urls.append(element)
        target_papers = []
        for tag in scrapped_course_urls:
            target_papers.append(tag.text)
        return_text = 'Returning to Qualification Details'
        while return_text in target_papers:
            target_papers.remove(return_text)
        iterator = 0
        temp_paper_code: str
        for paper in target_papers:
            if iterator % 2 is 0:
                dictionary['qualifications'][degree].setdefault(paper, [])
                temp_paper_code = paper
            else:
                dictionary['qualifications'][degree][temp_paper_code].append({'name': paper})
            iterator += 1
        counter += 1
    return dictionary
    
# add scrapped urls to target urls for the next round, then clear
def clean_up(is_refined: bool):
    target_urls.clear()
    for url in scrapped_urls:
        url = url.get('href')
        if not is_refined:
            url = url.replace('../', '')
        target_urls.append(url)
    scrapped_urls.clear()

# %%
# arion scrapping process_01 -> getting qualification type links
scrap_arion_urls()
clean_up(True)

# %%
# arion scrapping process_02 -> getting qualification liks
scrap_arion_urls()
qualification_dict = get_arion_entries('qualifications')
clean_up(True)
# Out:
# Doctor of Education
# Doctor of Health Science
# Doctor of Philosophy
# Master of Analytics
# Master of Applied Finance
# Master of Applied Science
# Master of Arts
# Master of Arts 1
# Master of Arts
# Master of Arts Management
# Master of Business
# Master of Business Administration
# Master of Communication Studies
# Master of Computer and Information Sciences
# Master of Computer and Information Sciences 2
# Master of Computer and Information Sciences
# Master of Construction Management
# Master of Creative Technologies
# Master of Creative Writing
# Master of Cultural and Creative Practice
# Master of Design
# Master of Education
# Master of Education Practice
# Master of Educational Leadership
# Master of Emergency Management
# Master of Emergency Management 3
# Master of Emergency Management
# Master of Engineering
# Master of Engineering Project Management
# Master of English and New Media Studies
# Master of Forensic Information Technology
# Master of Gastronomy
# Master of Geographic Information Science
# Master of Global Business
# Master of Health Informatics
# Master of Health Practice
# Master of Health Science
# Master of Human Rights
# Master of Information Security and Digital Forensics
# Master of International Hospitality Management
# Master of International Tourism Management
# Master of Laws
# Master of Maori and Indigenous Business
# Master of Marketing
# Master of Medical Laboratory Science
# Master of Performance and Media Arts
# Master of Philosophy
# Master of Professional Accounting
# Master of Professional Language Studies
# Master of Psychotherapy
# Master of Public Health
# Master of Science
# Master of Science 4
# Master of Science
# Master of Science 5
# Master of Science
# Master of Science (Research)
# Master of Science (Research) 6
# Master of Science (Research)
# Master of Science (Research) 7
# Master of Science (Research)
# Master of Service-Oriented Computing
# Master of Social Innovation
# Master of Sport and Exercise
# Master of Teaching and Learning
# Master of Visual Arts
# Postgraduate Diploma in Applied Finance
# Postgraduate Diploma in Applied Science
# Postgraduate Diploma in Arts
# Postgraduate Diploma in Arts 8
# Postgraduate Diploma in Arts
# Postgraduate Diploma in Brand Communication
# Postgraduate Diploma in Business
# Postgraduate Diploma in Business Administration
# Postgraduate Diploma in Clinical Child and Adolescent Psychotherapy
# Postgraduate Diploma in Communication Studies
# Postgraduate Diploma in Computer and Information Sciences
# Postgraduate Diploma in Counselling Psychology
# Postgraduate Diploma in Education
# Postgraduate Diploma in Education Practice
# Postgraduate Diploma in Emergency Management
# Postgraduate Diploma in Engineering
# Postgraduate Diploma in Gastronomy
# Postgraduate Diploma in Geographic Information Science
# Postgraduate Diploma in Global Business
# Postgraduate Diploma in Health Science
# Postgraduate Diploma in International Hospitality Management
# Postgraduate Diploma in International Tourism Management
# Postgraduate Diploma in Maori and Indigenous Business
# Postgraduate Diploma in Marketing
# Postgraduate Diploma in Medical Laboratory Science
# Postgraduate Diploma in Performance and Media Arts
# Postgraduate Diploma in Professional Accounting
# Postgraduate Diploma in Public Health
# Postgraduate Diploma in Registered Nurse Prescribing
# Postgraduate Diploma in Science
# Postgraduate Diploma in Science 9
# Postgraduate Diploma in Science
# Postgraduate Diploma in Social Innovation
# Postgraduate Diploma in Sport and Exercise
# Postgraduate Certificate in Advanced Nursing Practice
# Postgraduate Certificate in Applied Science
# Postgraduate Certificate in Arts
# Postgraduate Certificate in Arts 10
# Postgraduate Certificate in Arts
# Postgraduate Certificate in Business
# Postgraduate Certificate in Business Administration
# Postgraduate Certificate in Business Studies
# Postgraduate Certificate in Communication Studies
# Postgraduate Certificate in Computer and Information Sciences
# Postgraduate Certificate in Cultural and Creative Practice
# Postgraduate Certificate in Design
# Postgraduate Certificate in Education
# Postgraduate Certificate in Education Practice
# Postgraduate Certificate in Educational Leadership
# Postgraduate Certificate in Emergency Management
# Postgraduate Certificate in Engineering
# Postgraduate Certificate in Gastronomy
# Postgraduate Certificate in Health Science
# Postgraduate Certificate in International Hospitality Management
# Postgraduate Certificate in International Tourism Management
# Postgraduate Certificate in Law
# Postgraduate Certificate in Medical Laboratory Science
# Postgraduate Certificate in Professional Accounting
# Postgraduate Certificate in Public Health
# Postgraduate Certificate in Science
# Postgraduate Certificate in Science 11
# Postgraduate Certificate in Science
# Postgraduate Certificate in Social Innovation
# Postgraduate Certificate in Sport and Exercise
# Postgraduate Certificate in Visual Arts
# Bachelor of Applied Science (Honours)
# Bachelor of Art and Design (Honours)
# Bachelor of Arts (Honours)
# Bachelor of Business (Honours)
# Bachelor of Communication Studies (Honours)
# Bachelor of Computer and Information Sciences (Honours)
# Bachelor of Creative Technologies (Honours)
# Bachelor of Engineering (Honours)
# Bachelor of Health Science (Honours)
# Bachelor of Laws (Honours)
# Bachelor of Science (Honours)
# Bachelor of Science (Honours) 12
# Bachelor of Science (Honours)
# Bachelor of Sport and Recreation (Honours)
# Bachelor of Applied Science
# Bachelor of Arts
# Bachelor of Arts 13
# Bachelor of Arts
# Bachelor of Arts (NZSL-English Interpreting)
# Bachelor of Arts and Bachelor of Business Conjoint Degree
# Bachelor of Arts and Bachelor of Business Conjoint Degrees
# Bachelor of Arts and Bachelor of Computer and Information Sciences
# Bachelor of Business
# Bachelor of Business and Bachelor of Communication Studies conjoint degrees
# Bachelor of Business and Bachelor of Computer and Information Sciences Conjoint
# Bachelor of Business and Bachelor of Health Science Conjoint Degree
# Bachelor of Business and Bachelor of International Hospitality Management
# Bachelor of Business and Bachelor of Science Conjoint Degrees
# Bachelor of Business and Bachelor of Sport and Recreation Conjoint Degree
# Bachelor of Communication Studies
# Bachelor of Computer & Information Sciences and Bachelor of Science
# Bachelor of Computer and Information Sciences
# Bachelor of Creative Technologies
# Bachelor of Design
# Bachelor of Education (Specialty) Teaching
# Bachelor of Engineering Technology
# Bachelor of Health Science
# Bachelor of Health Science 14
# Bachelor of Health Science
# Bachelor of Health Science 15
# Bachelor of Health Science
# Bachelor of Health Science 16
# Bachelor of Health Science
# Bachelor of Health Science 17
# Bachelor of Health Science
# Bachelor of Health Science ( Midwifery )
# Bachelor of Health Science (Midwifery)
# Bachelor of Health Science (Nursing)
# Bachelor of Health Science (Occupational Therapy)
# Bachelor of Health Science (Physiotherapy)
# Bachelor of Health Science in Health Promotion
# Bachelor of Health Science in Oral Health
# Bachelor of Health Science in Paramedicine
# Bachelor of Health Science in Podiatry
# Bachelor of Health Science in Psychology
# Bachelor of International Hospitality Management
# Bachelor of International Tourism Management
# Bachelor of Laws
# Bachelor of Maori Development
# Bachelor of Mathematical Sciences
# Bachelor of Medical Laboratory Science
# Bachelor of Science
# Bachelor of Science 18
# Bachelor of Science
# Bachelor of Sport and Recreation
# Bachelor of Visual Arts
# Graduate Diploma in [Specialty] Education
# Graduate Diploma in Addictions
# Graduate Diploma in Advertising Creativity
# Graduate Diploma in Applied Science
# Graduate Diploma in Arts
# Graduate Diploma in Arts (Maori Development)
# Graduate Diploma in Business
# Graduate Diploma in Child Mental Health
# Graduate Diploma in Computer and Information Sciences
# Graduate Diploma in Health Science
# Graduate Diploma in International Hospitality Management
# Graduate Diploma in International Tourism Management
# Graduate Diploma in Mathematical Sciences
# Graduate Diploma in Pacific Journalism
# Graduate Diploma in Psychotherapy Studies
# Graduate Diploma in Science
# Graduate Diploma in Science 19
# Graduate Diploma in Science
# Graduate Diploma in Secondary Teaching
# Graduate Diploma in Sport and Exercise
# Graduate Certificate in Addictions
# Graduate Certificate in Applied Science
# Graduate Certificate in Arts
# Graduate Certificate in Arts 20
# Graduate Certificate in Arts
# Graduate Certificate in Business
# Graduate Certificate in Computer and Information Sciences
# Graduate Certificate in Emergency Management
# Graduate Certificate in Health Science
# Graduate Certificate in International Hospitality Management
# Graduate Certificate in International Tourism Management
# Graduate Certificate in Mathematical Sciences
# Graduate Certificate in Science
# Graduate Certificate in Science 21
# Graduate Certificate in Science
# Graduate Certificate in Sport & Exercise
# Diploma in Applied Science
# Diploma in Chinese
# Diploma in Culinary Arts
# Diploma in English Language
# Diploma in Fitness Training
# Diploma in Interpreting and Translation
# Diploma in Japanese
# Diploma in Mental Health Support Work
# Diploma in Military Medicine
# Diploma in Outdoor Recreation Leadership
# Diploma in Paramedic Science
# Diploma in Patisserie
# Diploma in Sport and Recreation
# Diploma in Sports Management and Exercise Science
# Diploma in Violence and Trauma Studies
# Certificate in [Specialty] Education
# Certificate in Anaesthetic Technology
# Certificate in Applied Mental Health
# Certificate in Applied Science
# Certificate in Applied Science 22
# Certificate in Applied Science
# Certificate in Business
# Certificate in Business Studies
# Certificate in Communication Studies
# Certificate in Emergency Management
# Certificate in Employment Skills English
# Certificate in English for Academic Study
# Certificate in English Language
# Certificate in Foundation Studies
# Certificate in Health Care Support
# Certificate in Health Studies
# Certificate in Hospitality and Tourism
# Certificate in Legal Studies
# Certificate in Pharmacy (Technician)
# Certificate in Practical Patisserie
# Certificate in Science and Technology
# Certificate in Social Sciences
# Certificate in Sport and Recreation

# %%
# arion scrapping process_03 -> getting table of papers links
scrap_arion_urls()
clean_up(False)

# %%
# arion scrapping process_04 -> gettting degrees with a set of papers
qualification_dict = get_arion_course_set(qualification_dict)

# %%
# arion scrapping process_05 -> getting paper links
scrap_arion_urls()

# %%
# arion scrapping process_06 -> getting a list of papers to parse in json for Rudy's paper list entity
paper_list = get_arion_paper_list()

# %%
# write a degree list with a corresponding set of papers to a json file for firebase
with open('degrees.json', 'w') as outfile:
    json.dump(qualification_dict, outfile, indent=4)

# %%
# write a paper list as a json file for dialogflow
with open('papers.json', 'w') as outfile:
    json.dump(paper_list, outfile, indent=4)
